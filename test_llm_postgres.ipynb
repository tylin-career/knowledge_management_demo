# %%
# !pip install langchain openai python-dotenv langchain-community tiktoken psycopg2-binary pgvector

# %%
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
loader = TextLoader('state_of_the_union.txt', encoding='utf-8')
documents = loader.load()
print(documents)
print(len(documents))
# Out:
# [Document(metadata={'source': 'state_of_the_union.txt'}, page_content='Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determ
# ...

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, 
    chunk_overlap=80
    )
texts = text_splitter.split_documents(documents)
print(texts[0])
print('----------------------')
print(f'Now we have {len(texts)} chunks')
# Out:
# page_content='Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# ...

# %%
embeddings = OpenAIEmbeddings()
vector = embeddings.embed_query('Testing the embedding model')
print(vector)
# Out:
# /tmp/ipykernel_26536/1982403625.py:1: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings()
# ...

# %%
len(vector)
# Out:
# 1536

# %%
doc_vectors = embeddings.embed_documents([t.page_content for t in texts[:5]])
print(doc_vectors)
print('----------------------')
print(len(doc_vectors))
# Out:
# [[-0.003606892537495954, -0.010445720588656282, -0.01858196772393737, -0.017878508050760297, 0.00587986559301913, 0.020015433491509468, 0.014945211393893886, -0.009609531603357448, -0.0031141385634777118, -0.006589961871500692, 0.015343396536291172, 0.008972436120579921, -0.020944532157103138, 0.0009224619438738471, 0.001971015896072968, 0.006347732762806876, 0.01819705579214906, -0.014706300122190982, 0.02962496602618958, -0.022417815693856834, 0.009755533194765518, -0.01319319695361036, 0.015330123325682198, 0.012403463274120275, -0.0005989366320913851, 0.010989906391138974, 0.03695157152871245, -0.034058093572350304, 0.0191792454375333, -0.02448837880685179, -0.01243664536932005, -0.02973114798577073, -0.023957465283655405, -0.004788174754078838, -0.024833472969458502, -0.020944532157103138, -0.013345834219000255, -0.012277371498625667, 0.00354384664974865, -0.018515603533537824, 0.007432786996442682, -0.0022879047189662757, -0.011056270581538522, 0.005753773351863191, -0.02474056
# ...

# %%
doc_vectors[0]
# Out:
# [-0.003606892537495954,
#  -0.010445720588656282,
#  -0.01858196772393737,
#  -0.017878508050760297,
#  0.00587986559301913,
#  0.020015433491509468,
#  0.014945211393893886,
#  -0.009609531603357448,
#  -0.0031141385634777118,
#  -0.006589961871500692,
#  0.015343396536291172,
#  0.008972436120579921,
#  -0.020944532157103138,
#  0.0009224619438738471,
#  0.001971015896072968,
#  0.006347732762806876,
#  0.01819705579214906,
#  -0.014706300122190982,
#  0.02962496602618958,
#  -0.022417815693856834,
#  0.009755533194765518,
#  -0.01319319695361036,
#  0.015330123325682198,
#  0.012403463274120275,
#  -0.0005989366320913851,
#  0.010989906391138974,
#  0.03695157152871245,
#  -0.034058093572350304,
#  0.0191792454375333,
#  -0.02448837880685179,
#  -0.01243664536932005,
#  -0.02973114798577073,
#  -0.023957465283655405,
#  -0.004788174754078838,
#  -0.024833472969458502,
#  -0.020944532157103138,
#  -0.013345834219000255,
#  -0.012277371498625667,
#  0.00354384664974865,
# ...

# %%
from langchain_community.vectorstores import PGVector

CONNECTION_STRING = "postgresql+psycopg2://postgres:test@localhost:5432/vector_db"
COLLECTION_NAME = "state_of_union_vectors"

db = PGVector.from_documents(
    embedding=embeddings,
    documents=texts,
    connection_string=CONNECTION_STRING,
    collection_name=COLLECTION_NAME
)
# Out:
# /home/biguser/codeFactory/LLM_RAG_repo/repo/venv/lib/python3.12/site-packages/langchain_community/vectorstores/pgvector.py:487: LangChainPendingDeprecationWarning: Please use JSONB instead of JSON for metadata. This change will allow for more efficient querying that involves filtering based on metadata. Please note that filtering operators have been changed when using JSONB metadata to be prefixed with a $ sign to avoid name collisions with columns. If you're using an existing database, you will need to create a db migration for your metadata column to be JSONB and update your queries to use the new operators.
#   store = cls(

# %%
query = "What did the president say about Russia"

similar_docs = db.similarity_search_with_score(query, k=2)

for doc, score in similar_docs:
    print(doc.page_content)
    print(score)
    print('----------------------')
# Out:
# Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.
# 0.1585635135845498
# ...

# %%
print(embeddings.embed_query(query))
# Out:
# [-0.020186410805225725, -0.011743180214317344, 0.005130390532007023, -0.0036737722526885234, -0.0038574607256245666, -0.012323249811475286, -0.013818539397270981, -0.018974711731585357, -0.010898857155226505, -0.005871590107158672, 0.03905799905287189, 0.00598760402659026, -0.00691571491638169, -0.030086259675452608, 0.013650963735869798, -0.002855230064582483, 0.027456612697648382, -0.03472681645271615, 0.05486166365332717, -0.015803666463100385, -0.004456865510359829, -0.012929100279618026, 0.0031227063682191174, -0.007411996682839041, -0.016293501149166424, -0.0009095808887711067, 0.02620624138620826, -0.024930089203783343, 0.0007355600678313838, -0.012987106773672543, 0.008352997542461592, -0.027998010988329127, -0.02161724821355943, -0.006255080330226895, -0.020521562128028092, -0.027198803987800408, -0.007295982763407452, -0.020392657773104107, 0.009584033666324392, -0.013064449386626934, 0.022429346580903103, 0.006902824480889291, 0.01646107774189016, -0.003880018987736264, -0
# ...

# %%
# 使用 distance（越小越相似）
results_distance = db.similarity_search_with_score(query, k=2)
for doc, distance in results_distance:
    print(f"Distance: {distance}")  # 較小的值表示更相似

# 使用 relevance score（越大越相似）
results_score = db.similarity_search_with_relevance_scores(query, k=2)
for doc, score in results_score:
    print(f"Relevance Score: {score}")  # 較大的值表示更相似
# Out:
# Distance: 0.1585635135845498
# Distance: 0.16372551485603626
# Relevance Score: 0.8414364864154502
# Relevance Score: 0.8362744851439637

# %%
retriever = db.as_retriever(search_kwargs=({'k': 6}))
retriever
# Out:
# VectorStoreRetriever(tags=['PGVector', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.pgvector.PGVector object at 0x7f5adb7cd160>, search_kwargs={'k': 6})

# %%
retriever.invoke(query)
# Out:
# [Document(metadata={'source': 'state_of_the_union.txt'}, page_content='Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determ
# ...

# %%
from langchain.chains import RetrievalQA
from langchain.llms import OpenAI

# create RetrievalQA chain for question-answering
qa = RetrievalQA.from_chain_type(llm=OpenAI(), chain_type="stuff", retriever=retriever)
# Out:
# /tmp/ipykernel_26536/3123195439.py:5: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAI``.
#   qa = RetrievalQA.from_chain_type(llm=OpenAI(), chain_type="stuff", retriever=retriever)

# %%
query = "What did the president say about Russia"
qa.run(query)
# Out:
# /tmp/ipykernel_26536/2756193604.py:2: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   qa.run(query)
# " The president said that Putin's latest attack on Ukraine was premeditated and unprovoked. He also mentioned that the U.S. and other countries have taken measures to hold Russia accountable, including imposing economic sanctions and releasing oil reserves. Additionally, he mentioned providing support to Ukraine in their fight for freedom."

# %% [markdown]
# This entire process is referred to as Retrieval Augmented Generation - which makes sense, as we're:
#
# Retrieving the most relevant documents from the vector database.
# Augmenting our prompts/questions with the context from those documents
# Generating responses that are informed by that context.

# %%
from langchain.prompts import PromptTemplate

prompt_template = """Use the following pieces of context to answer the question at the end. 
If you don't know the answer, just say that you don't know, don't try to make up an answer.

{context}

Question: {question}
Return an answer in polite Traditional Chinese:
"""
PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)

# %%
chain_type_kwargs = {"prompt": PROMPT}
qa = RetrievalQA.from_chain_type(
    llm=OpenAI(),
    chain_type="stuff",
    retriever=retriever,
    chain_type_kwargs=chain_type_kwargs   # pass kwargs here
)

# %%
query = "What did the president say about Russia"
qa.run(query)
# Out:
# ' \n總統提到俄羅斯時表示，俄羅斯總統普京最近對烏克蘭的侵略行為是事先計畫且無端挑釁的，美國和其他自由國家都將對此採取行動並對俄羅斯實施制裁，以支持烏克蘭人民的自由和抵抗俄羅斯的侵略。他也宣布美國將和盟友一起，限制俄羅斯飛機進入美國領空，並透過各種方式削弱俄羅斯的經濟和軍事力量。同時，美國也將提供超過10億美元的直接援助給烏克蘭，以'

# %%
query = "What did the president say about Russia"
qa.run(query)
# Out:
# '\n總統提到俄羅斯，他說俄羅斯總統普京錯估了情勢，企圖侵略烏克蘭，但遭到自由世界的抵制。美國與其他自由國家結成聯盟，採取多項措施制裁俄羅斯，並支持烏克蘭人民的自由。總統也宣布將與盟友一起封鎖俄羅斯的飛行空域，對俄羅斯經濟施加更大壓力。此外，美國也提供了超過10億美元的直接援助給烏克蘭。總統強調，俄羅斯的侵略行為導致自'

# %%
del db

# %%
db = PGVector(
    embedding_function=embeddings,
    connection_string=CONNECTION_STRING,
    collection_name=COLLECTION_NAME
)
retriever = db.as_retriever(search_kwargs=({'k': 6}))

chain_type_kwargs = {"prompt": PROMPT}
qa = RetrievalQA.from_chain_type(
    llm=OpenAI(),
    chain_type="stuff",
    retriever=retriever,
    chain_type_kwargs=chain_type_kwargs   # pass kwargs here
)
query = "What did the president say about Russia"
qa.run(query)
# Out:
# /tmp/ipykernel_26536/198344077.py:1: LangChainPendingDeprecationWarning: Please use JSONB instead of JSON for metadata. This change will allow for more efficient querying that involves filtering based on metadata. Please note that filtering operators have been changed when using JSONB metadata to be prefixed with a $ sign to avoid name collisions with columns. If you're using an existing database, you will need to create a db migration for your metadata column to be JSONB and update your queries to use the new operators.
#   db = PGVector(
# '\n總統提到俄羅斯是一個入侵外國的獨裁者，他的行為帶來了全球的代價。美國正在與30多個國家合作，對俄羅斯實施經濟制裁，並提供軍事、經濟和人道主義援助給烏克蘭。總統也宣布將與盟國一起封鎖俄羅斯的航班，進一步孤立俄羅斯並對其經濟造成壓力。總統也指出，俄羅斯的經濟正在受到嚴重打擊，而普京應該為此負責。'

# %%
import getpass
import os

# %%
os.environ["OPENAI_API_KEY"] = getpass.getpass()

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %%
from sqlalchemy import create_engine

connection = "postgresql+psycopg://postgres:mysecretpassword@localhost:5432/langchain"
engine = create_engine(connection)

try:
    with engine.connect() as conn:
        print("Connection successful!")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Connection successful!

# %%
# LLM
